# %%
from google.colab import drive
drive.mount("/content/drive/", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import json
import pandas as pd
import numpy as np
import os, os.path
import time
import csv

# %%
N_FACE = 70
N_POSE = 8
FOLDER = './drive/My Drive/636/data/json/'
CSV_FOLDER = './drive/My Drive/636/data/csv/'
LABEL_FOLDER = './drive/My Drive/636/data/label/'
COL_NAMES = ['vid', 'frame', 'label']
COL_NAMES += ['f_' + str(i) for i in range(N_FACE * 2)]
COL_NAMES += ['p_' + str(i) for i in range(N_POSE * 2)]

# %%
droplist_f = set([(i * 3 + 2) for i in range(N_FACE)])
droplist_p = set([(i * 3 + 2) for i in range(N_POSE)])
idx_f = [i for i in range(N_FACE * 3) if (i not in droplist_f)]
idx_p = [i for i in range(N_POSE * 3) if (i not in droplist_p)]

# %%
# collect the json output of openpose and combine them into csv
def json_to_csv(folderpath, csv_path, raw_label, vid):
  start_time = time.time()
  idx = 0
  write_file = open(csv_path, 'w')
  csv_writer = csv.writer(write_file)
  csv_writer.writerow(COL_NAMES) 
  for name in sorted(os.listdir(folderpath)): 
    if idx < 3600 and name[-4:] == 'json':
      if idx % 500 == 0:
        print(idx)
      filepath = os.path.join(folderpath, name)
      if os.path.isfile(filepath):
        with open(filepath, 'r') as f:
          data = json.load(f)['people']
          if len(data) > 0:
            row = [vid, name, raw_label[idx]]
            row_face = [float(data[0]['face_keypoints_2d'][j]) for j in idx_f]
            row_pose = [float(data[0]['pose_keypoints_2d'][j]) for j in idx_p]
            row += row_face + row_pose
            row = np.array(row)
            csv_writer.writerow(row)
      idx += 1
    elif idx >= 3600:
      break
  end_time = time.time()
  print(end_time-start_time)

# %%
def get_csv(i, label):
  folderpath = FOLDER + str(i) + '/'
  csv_path = CSV_FOLDER + str(i) + '.csv'
  json_to_csv(folderpath, csv_path, label, i)

# %%
label_8 = [0 for i in range(3600)]
for i in range(30*7, 30*112):
  label_8[i] = 1

get_csv(8, label_8)
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 2735.6123678684235

# %%
# collect the json output of openpose and combine them into csv
def json_to_csv(folderpath, csv_path, raw_label, vid):
  start_time = time.time()
  idx = 0
  write_file = open(csv_path, 'w')
  csv_writer = csv.writer(write_file)
  csv_writer.writerow(COL_NAMES) 
  for name in sorted(os.listdir(folderpath)): 
    if name[-4:] == 'json':
      if idx % 500 == 0:
        print(idx)
      filepath = os.path.join(folderpath, name)
      if os.path.isfile(filepath):
        with open(filepath, 'r') as f:
          data = json.load(f)['people']
          if len(data) > 0:
            row = [vid, name, raw_label[idx]]
            row_face = [float(data[0]['face_keypoints_2d'][j]) for j in idx_f]
            row_pose = [float(data[0]['pose_keypoints_2d'][j]) for j in idx_p]
            row += row_face + row_pose
            row = np.array(row)
            csv_writer.writerow(row)
      idx += 1
  end_time = time.time()
  print(end_time-start_time)

# %%
label_9 = [0 for i in range(7108)]
for i in range(24*120, 24*122):
  label_9[i] = 1
for i in range(24*139, 24*157):
  label_9[i] = 1
for i in range(24*179, 24*219):
  label_9[i] = 1

get_csv(9, label_9)
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 5093.208770990372

# %%
# collect the json output of openpose and combine them into csv
def json_to_csv(folderpath, csv_path, raw_label, vid):
  start_time = time.time()
  idx = 0
  write_file = open(csv_path, 'w')
  csv_writer = csv.writer(write_file)
  csv_writer.writerow(COL_NAMES) 
  for name in sorted(os.listdir(folderpath))[300:]: 
    if name[-4:] == 'json':
      if idx % 500 == 0:
        print(idx)
      filepath = os.path.join(folderpath, name)
      if os.path.isfile(filepath):
        with open(filepath, 'r') as f:
          data = json.load(f)['people']
          if len(data) > 0:
            row = [vid, name, raw_label[idx]]
            row_face = [float(data[0]['face_keypoints_2d'][j]) for j in idx_f]
            row_pose = [float(data[0]['pose_keypoints_2d'][j]) for j in idx_p]
            row += row_face + row_pose
            row = np.array(row)
            csv_writer.writerow(row)
      idx += 1
  end_time = time.time()
  print(end_time-start_time)

# %%
label_12 = [0 for i in range(1158)]
for i in range(25*9, 1158):
  label_12[i] = 1

get_csv(12, label_12)
# Out:
# 0
# 500
# 1000
# 722.3214461803436

# %%
# collect the json output of openpose and combine them into csv
def json_to_csv(folderpath, csv_path, raw_label, vid):
  start_time = time.time()
  idx = 0
  write_file = open(csv_path, 'w')
  csv_writer = csv.writer(write_file)
  csv_writer.writerow(COL_NAMES) 
  for name in sorted(os.listdir(folderpath)): 
    if name[-4:] == 'json':
      if idx % 100 == 0:
        print(idx)
      filepath = os.path.join(folderpath, name)
      if os.path.isfile(filepath):
        with open(filepath, 'r') as f:
          data = json.load(f)['people']
          if len(data) > 0:
            row = [vid, name, raw_label[idx]]
            row_face = [float(data[0]['face_keypoints_2d'][j]) for j in idx_f]
            row_pose = [float(data[0]['pose_keypoints_2d'][j]) for j in idx_p]
            row += row_face + row_pose
            row = np.array(row)
            csv_writer.writerow(row)
      idx += 1
  end_time = time.time()
  print(end_time-start_time)

# %%
pwd
# Out:
# '/content'

# %%
label_18 = [0 for i in range(300)]
for i in range(300):
  label_18[i] = 1

get_csv(18, label_18)
# Out:
# 0
# 100
# 200
# 100.17468619346619

# %%
label_19 = [0 for i in range(180)]
for i in range(61, 180):
  label_19[i] = 1

get_csv(19, label_19)
# Out:
# 0
# 100
# 58.55461239814758

# %% [markdown]
# 20 21 no json

# %%
# label_20 = [0 for i in range(145)]
# for i in range(13, 145):
#   label_20[i] = 1

# get_csv(20, label_20)
# Out:
# 0.006109476089477539

# %%
label_22 = [0 for i in range(32)]
get_csv(22, label_22)
# Out:
# 0
# 12.386115074157715

# %%
label_23 = [0 for i in range(121)]
get_csv(23, label_23)
# Out:
# 0
# 100
# 38.980101108551025

# %%
label_24 = [0 for i in range(71)]
get_csv(24, label_24)
# Out:
# 0
# 21.824249744415283

# %%
label_25 = [0 for i in range(95)]
get_csv(25, label_25)
# Out:
# 0
# 29.323594570159912

# %%
label_26 = [0 for i in range(100)]
get_csv(26, label_26)
# Out:
# 0
# 31.337227821350098

# %%
# collect the json output of openpose and combine them into csv
def json_to_csv(folderpath, csv_path, raw_label, vid):
  start_time = time.time()
  idx = 0
  write_file = open(csv_path, 'w')
  csv_writer = csv.writer(write_file)
  csv_writer.writerow(COL_NAMES) 
  for name in sorted(os.listdir(folderpath)): 
    if name[-4:] == 'json':
      if idx % 100 == 0:
        print(idx)
      filepath = os.path.join(folderpath, name)
      if os.path.isfile(filepath):
        with open(filepath, 'r') as f:
          data = json.load(f)['people']
          if len(data) > 0:
            row = [vid, name, raw_label[idx]]
            row_face = [float(data[0]['face_keypoints_2d'][j]) for j in idx_f]
            row_pose = [float(data[0]['pose_keypoints_2d'][j]) for j in idx_p]
            row += row_face + row_pose
            row = np.array(row)
            csv_writer.writerow(row)
      idx += 1
  end_time = time.time()
  print(end_time-start_time)

# %%
label_0 = [0 for i in range(2331)]
for i in range(29 * 30, 37 * 30):
  label_0[i] = 1
for i in range(50 * 30, 69 * 30):
  label_0[i] = 1
get_csv(0, label_0)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 723.4105887413025
