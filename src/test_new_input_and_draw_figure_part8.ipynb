# %%
from google.colab import drive
drive.mount("/content/drive/", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %% [markdown]
# Read input video

# %%
import json
import pandas as pd
import numpy as np
import os, os.path
import csv

# %%
N_FACE = 70
N_POSE = 8
FOLDER = './openpose/output/'
CSV_FOLDER = './drive/My Drive/636/sample_part5/csv/'
JSON_FOLDER = './drive/My Drive/636/sample_part8/json/'
FIG_FOLDER = './drive/My Drive/636/sample_part8/fig/'
MODEL_FOLDER = './drive/My Drive/636/model/part8/'
COL_NAMES = ['vid', 'frame']
COL_NAMES += ['f_' + str(i) for i in range(N_FACE * 2)]
COL_NAMES += ['p_' + str(i) for i in range(N_POSE * 2)]
droplist_f = set([(i * 3 + 2) for i in range(N_FACE)])
droplist_p = set([(i * 3 + 2) for i in range(N_POSE)])
idx_f = [i for i in range(N_FACE * 3) if (i not in droplist_f)]
idx_p = [i for i in range(N_POSE * 3) if (i not in droplist_p)]

# %%
df_list = []
for i in range(1, 6):
  df = pd.read_csv(CSV_FOLDER + str(i) + '.csv')
  df_list.append(df)

# %%
for i in range(5):
  df_list[i] = df_list[i][df_list[i].columns[2:]]

# %%
df_list
# Out:
# [         f_0      f_1      f_2      f_3  ...  p_12  p_13  p_14  p_15
#  0    608.104  182.533  605.245  218.262  ...   0.0   0.0   0.0   0.0
#  1    601.576  177.755  595.971  214.185  ...   0.0   0.0   0.0   0.0
#  2    593.186  178.170  588.916  216.601  ...   0.0   0.0   0.0   0.0
#  3    591.117  173.803  586.904  208.908  ...   0.0   0.0   0.0   0.0
#  4    584.937  173.060  582.150  209.282  ...   0.0   0.0   0.0   0.0
#  ..       ...      ...      ...      ...  ...   ...   ...   ...   ...
#  349  590.188  183.864  555.773  258.128  ...   0.0   0.0   0.0   0.0
#  350  580.039  184.403  539.941  255.488  ...   0.0   0.0   0.0   0.0
#  351  556.902  183.543  510.500  248.927  ...   0.0   0.0   0.0   0.0
#  352  563.328  185.735  523.478  260.001  ...   0.0   0.0   0.0   0.0
#  353    0.000    0.000    0.000    0.000  ...   0.0   0.0   0.0   0.0
#
#  [354 rows x 156 columns],
#              f_0      f_1         f_2  ...     p_13     p_14     p_15
#  0    150.909000  116.604  151.716000  ...    0.000    0.000    0.000
#  1    151.057000  115.868  151.865000  ...    0.000    0.000    0.000
#  2    150.865000  116.095  151.675000  ...    0.000    0.000    0.000
#  3    151.351000  116.085  152.977000  ...    0.000    0.000    0.000
#  4    151.017000  116.359  151.819000  ...    0.000    0.000    0.000
#  ..          ...      ...         ...  ...      ...      ...      ...
#  204    0.000000    0.000    0.000000  ...  265.422  379.813  290.842
#  205    0.000000    0.000    0.000000  ...    0.000    0.000    0.000
#  206    0.000000    0.000    0.000000  ...    0.000    0.000    0.000
#  207    0.000000    0.000    0.000000  ...    0.000    0.000    0.000
#  208    0.960756  193.506   -0.820483  ...    0.000    0.000    0.000
#
#  [209 rows x 156 columns],
#           f_0       f_1      f_2       f_3  ...      p_12     p_13     p_14     p_15
#  0    552.637  232.4740  558.096  269.3180  ...     0.000    0.000    0.000    0.000
#  1    552.637  232.4740  558.095  269.3170  ...     0.000    0.000    0.000    0.000
#  2    550.940  235.5180  554.999  272.0480  ...     0.000    0.000    0.000    0.000
#  3    907.739   30.5895  908.072   39.5927  ...   923.226  194.479  884.088  225.757
#  4    907.967   31.5107  902.198   37.9590  ...   923.237  194.461  868.375  225.862
#  ..       ...       ...      ...       ...  ...       ...      ...      ...      ...
#  445  588.821  223.3820  588.821  260.6550  ...  1103.500  715.608    0.000    0.000
#  446  591.950  231.4080  593.243  268.9290  ...  1101.490  715.624    0.000    0.000
#  447  590.673  229.9590  591.971  267.6110  ...     0.000    0.000    0.000    0.000
#  448  588.928  237.2360  591.530  272.3650  ...  1101.490  715.615    0.000    0.000
#  449  584.961  233.6850  586.238  272.0020  ...  1099.560  715.616    0.000    0.000
#
#  [450 rows x 156 columns],
#           f_0      f_1      f_2      f_3  ...     p_12     p_13     p_14     p_15
#  0    515.687  223.949  516.207  240.096  ...  838.997  515.739  897.753  584.302
#  1    514.899  224.185  516.454  240.773  ...  839.043  517.694  897.773  584.323
#  2    514.392  222.667  516.483  240.446  ...  839.050  517.701  897.780  584.325
#  3    515.451  223.713  517.019  240.447  ...  839.052  517.697  897.798  584.329
#  4    515.994  223.215  517.040  240.467  ...  838.998  513.811  897.779  584.323
#  ..       ...      ...      ...      ...  ...      ...      ...      ...      ...
#  445  561.632  193.748  562.275  213.690  ...  874.268  584.299  776.270  592.204
#  446  561.258  192.459  562.535  212.883  ...  874.269  584.289  776.298  594.083
#  447  561.008  193.322  562.278  213.633  ...  874.258  580.424  776.346  598.014
#  448  559.801  192.987  561.090  212.975  ...  872.338  580.403  776.365  596.083
#  449  558.874  193.654  561.475  213.806  ...  872.357  580.394  776.380  596.052
#
#  [450 rows x 156 columns],
#           f_0      f_1      f_2      f_3  ...      p_12     p_13     p_14     p_15
#  0    452.084  244.970  458.731  280.860  ...  1048.620  715.587    0.000    0.000
#  1    452.994  244.609  458.314  280.521  ...  1044.720  705.804    0.000    0.000
#  2    452.071  245.052  459.994  280.704  ...  1052.550  715.599    0.000    0.000
#  3    452.585  245.967  459.196  280.340  ...  1050.590  715.596    0.000    0.000
#  4    451.555  245.627  459.488  280.005  ...  1054.480  715.609    0.000    0.000
#  ..       ...      ...      ...      ...  ...       ...      ...      ...      ...
#  445  493.368  239.573  493.368  276.658  ...   792.030  556.871  646.964  468.725
#  446  490.910  239.557  489.935  273.696  ...   901.664  697.963  819.434  586.283
#  447  488.214  239.606  488.214  274.662  ...     0.000    0.000    0.000    0.000
#  448  488.082  240.810  486.197  274.738  ...     0.000    0.000    0.000    0.000
#  449  485.575  239.958  485.575  276.365  ...     0.000    0.000    0.000    0.000
#
#  [450 rows x 156 columns]]

# %% [markdown]
# Reshape Data into Segments and Prepare for Keras

# %%
# slice every TIME_STEP frame as a segment until from 1st frame to last, if null, make up with 0
def get_slices(df, fps, TIME_STEP):
  slices = []
  ts = []
  for i in range(df.shape[0]):
    ts.append(i/fps)
    if i + 1 < TIME_STEP:
      slice_ = df.values[df.index[0 : i + 1]]
      fillzero = np.zeros((TIME_STEP - i - 1, df.shape[1]))
      slice_ = np.concatenate((slice_, fillzero), axis=0)
      slices.append(slice_)
    else:
      slices.append(df.values[df.index[i + 1 - TIME_STEP : i + 1]])

  slices_arr = np.asarray(slices, dtype= np.float32)
  ts_arr = np.asarray(ts, dtype= np.float32)
  return slices_arr, ts_arr

# %% [markdown]
# Load model and weight

# %%
# %tensorflow_version 1.x
from keras.layers.embeddings import Embedding
from keras.models import Sequential
from keras.layers import Dense, LSTM, LSTM, Dropout, Flatten
from keras.callbacks import History, EarlyStopping
from keras.models import load_model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
from keras.utils import np_utils
from keras.models import Sequential, Model, model_from_json
from keras.layers import Conv1D, Activation, MaxPooling1D, Conv2D, Activation, MaxPooling2D, Dropout, Dense, LSTM, BatchNormalization, Flatten
from keras.callbacks import ModelCheckpoint

# %%
from keras.layers import TimeDistributed

# %% [markdown]
# Draw figure

# %%
import matplotlib.pyplot as plt
from google.colab import files

def drawplt(time, pred, fig_name):
  plt.figure(figsize=(12,8))
  # plt.plot(time, pred, 'b', label='prediction', markersize=1)
  plt.plot(time, pred, 'b', label='prediction', markersize=3, color='red')
  plt.title('Prediction over time')
  my_y_ticks = np.arange(0, 1, 0.1)
  plt.yticks(my_y_ticks)
  plt.legend() 
  plt.savefig(fig_name)

# %% [markdown]
# Generate json

# %%
import json
def to_json(filepath):
  np_pred = np.array((ts_arr, y_pred.flatten())).T
  pred_list = np_pred.tolist()
  pred_dict = {"cry":pred_list}
  pred_json = json.dumps(pred_dict)
  with open(filepath, 'w') as json_file:
    json_file.write(pred_json)

# %% [markdown]
# Automation

# %%
model = load_model(MODEL_FOLDER + 'big_7859.h5')
model.summary()
for i in range(len(df_list)):
  # get dataframe
  df = df_list[i]
  # get input and timestamp
  t = 15.0
  frames = df.shape[0]
  fps = frames / t
  X_arr, ts_arr = get_slices(df, fps, 10)
  X_arr = X_arr.reshape(X_arr.shape[0], 40, 39, 1)
  # get prediction
  y_pred = model.predict(X_arr)
  # draw plot
  fig_name = FIG_FOLDER + 'big_7859' + str(i + 1) + '.png'
  drawplt(ts_arr, y_pred, fig_name)
  # output json file
  json_name = JSON_FOLDER + 'big_7859' + str(i + 1) + '.json'
  to_json(json_name)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 38, 37, 64)        640
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 36, 35, 64)        36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 18, 17, 64)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 18, 17, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 16, 15, 128)       73856
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 14, 13, 128)       147584
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 7, 6, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 5376)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1024)              5506048
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 6,815,681
# Trainable params: 6,815,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = load_model(MODEL_FOLDER + 'big_7571.h5')
model.summary()
for i in range(len(df_list)):
  # get dataframe
  df = df_list[i]
  # get input and timestamp
  t = 15.0
  frames = df.shape[0]
  fps = frames / t
  X_arr, ts_arr = get_slices(df, fps, 10)
  X_arr = X_arr.reshape(X_arr.shape[0], 40, 39, 1)
  # get prediction
  y_pred = model.predict(X_arr)
  # draw plot
  fig_name = FIG_FOLDER + 'big_7571' + str(i + 1) + '.png'
  drawplt(ts_arr, y_pred, fig_name)
  # output json file
  json_name = JSON_FOLDER + 'big_7571' + str(i + 1) + '.json'
  to_json(json_name)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 38, 37, 64)        640
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 36, 35, 64)        36928
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 18, 17, 64)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 18, 17, 64)        0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 16, 15, 128)       73856
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 14, 13, 128)       147584
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 7, 6, 128)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 5376)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1024)              5506048
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 6,815,681
# Trainable params: 6,815,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = load_model(MODEL_FOLDER + 'model1_7058.h5')
model.summary()
for i in range(len(df_list)):
  # get dataframe
  df = df_list[i]
  # get input and timestamp
  t = 15.0
  frames = df.shape[0]
  fps = frames / t
  X_arr, ts_arr = get_slices(df, fps, 10)
  # get prediction
  y_pred = model.predict(X_arr)
  # draw plot
  fig_name = FIG_FOLDER + 'model1_7058' + str(i + 1) + '.png'
  drawplt(ts_arr, y_pred, fig_name)
  # output json file
  json_name = JSON_FOLDER + 'model1_7058' + str(i + 1) + '.json'
  to_json(json_name)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-83f7aa7dd2db> in <module>()
# ----> 1 model = load_model(MODEL_FOLDER + 'model1_7058.h5')
#       2 model.summary()
#       3 for i in range(len(df_list)):
#       4   # get dataframe
#       5   df = df_list[i]
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     581
#     582     if H5Dict.is_supported_type(filepath):
# --> 583         with H5Dict(filepath, mode='r') as h5dict:
#     584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/io_utils.py in __init__(self, path, mode)
#     189             self._is_file = False
#     190         elif isinstance(path, six.string_types) or _is_path_instance(path):
# --> 191             self.data = h5py.File(path, mode=mode)
#     192             self._is_file = True
#     193         elif isinstance(path, dict):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = './drive/My Drive/636/model/part8/model1_7058.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
model = load_model(MODEL_FOLDER + 'model5_6921.h5')
for i in range(len(df_list)):
  # get dataframe
  df = df_list[i]
  # get input and timestamp
  t = 15.0
  frames = df.shape[0]
  fps = frames / t
  X_arr, ts_arr = get_slices(df, fps, 10)
  # get prediction
  y_pred = model.predict(X_arr)
  # draw plot
  fig_name = FIG_FOLDER + 'model5_6921' + str(i + 1) + '.png'
  drawplt(ts_arr, y_pred, fig_name)
  # output json file
  json_name = JSON_FOLDER + 'model5_6921' + str(i + 1) + '.json'
  to_json(json_name)

# %%
model = load_model(MODEL_FOLDER + 'model7_1_7037.h5')
for i in range(len(df_list)):
  # get dataframe
  df = df_list[i]
  # get input and timestamp
  t = 15.0
  frames = df.shape[0]
  fps = frames / t
  X_arr, ts_arr = get_slices(df, fps, 10)
  # get prediction
  y_pred = model.predict(X_arr)
  # draw plot
  fig_name = FIG_FOLDER + 'model7_1_7037' + str(i + 1) + '.png'
  drawplt(ts_arr, y_pred, fig_name)
  # output json file
  json_name = JSON_FOLDER + 'model7_1_7037' + str(i + 1) + '.json'
  to_json(json_name)

# %%
model = load_model(MODEL_FOLDER + 'model1_6884.h5')
for i in range(len(df_list)):
  # get dataframe
  df = df_list[i]
  # get input and timestamp
  t = 15.0
  frames = df.shape[0]
  fps = frames / t
  X_arr, ts_arr = get_slices(df, fps, 10)
  # get prediction
  y_pred = model.predict(X_arr)
  # draw plot
  fig_name = FIG_FOLDER + 'model1_6884' + str(i + 1) + '.png'
  drawplt(ts_arr, y_pred, fig_name)
  # output json file
  json_name = JSON_FOLDER + 'model1_6884' + str(i + 1) + '.json'
  to_json(json_name)

# %%
model = load_model(MODEL_FOLDER + 'model6_6644.h5')
for i in range(len(df_list)):
  # get dataframe
  df = df_list[i]
  # get input and timestamp
  t = 15.0
  frames = df.shape[0]
  fps = frames / t
  X_arr, ts_arr = get_slices(df, fps, 10)
  X_arr_r = X_arr.reshape((X_arr.shape[0], 1, 10, 156))
   # get prediction
  y_pred = model.predict(X_arr)
  # draw plot
  fig_name = FIG_FOLDER + 'model6_6644' + str(i + 1) + '.png'
  drawplt(ts_arr, y_pred, fig_name)

# %%
ls './drive/My Drive/636/model/part8'
# Out:
# model1_6884.h5  model5_6921.h5    model6_6644.h5    model7_6252.h5
# model1_7058.h5  model6_1_5671.h5  model7_1_7037.h5  model8_5856.h5

# %%
model = load_model(MODEL_FOLDER + 'model8_5856.h5')
for i in range(len(df_list)):
  # get dataframe
  df = df_list[i]
  # get input and timestamp
  t = 15.0
  frames = df.shape[0]
  fps = frames / t
  X_arr, ts_arr = get_slices(df, fps, 10)
  X_arr_r = X_arr.reshape((X_arr.shape[0], 1, 10, 156))
   # get prediction
  y_pred = model.predict(X_arr)
  # draw plot
  fig_name = FIG_FOLDER + 'model8_5856' + str(i + 1) + '.png'
  drawplt(ts_arr, y_pred, fig_name)

# %%
model = load_model(MODEL_FOLDER + 'model10_6336.h5')
for i in range(len(df_list)):
  # get dataframe
  df = df_list[i]
  # get input and timestamp
  t = 15.0
  frames = df.shape[0]
  fps = frames / t
  X_arr, ts_arr = get_slices(df, fps, 10)
  X_arr_r = X_arr.reshape((X_arr.shape[0], 1, 10, 156))
   # get prediction
  y_pred = model.predict(X_arr)
  # draw plot
  fig_name = FIG_FOLDER + 'model10_6336' + str(i + 1) + '.png'
  drawplt(ts_arr, y_pred, fig_name)

# %%
model = load_model(MODEL_FOLDER + 'model10_6590.h5')
for i in range(len(df_list)):
  # get dataframe
  df = df_list[i]
  # get input and timestamp
  t = 15.0
  frames = df.shape[0]
  fps = frames / t
  X_arr, ts_arr = get_slices(df, fps, 10)
  X_arr_r = X_arr.reshape((X_arr.shape[0], 1, 10, 156))
   # get prediction
  y_pred = model.predict(X_arr)
  # draw plot
  fig_name = FIG_FOLDER + 'model10_6590' + str(i + 1) + '.png'
  drawplt(ts_arr, y_pred, fig_name)

# %%
model = load_model(MODEL_FOLDER + 'model10_6364.h5')
for i in range(len(df_list)):
  # get dataframe
  df = df_list[i]
  # get input and timestamp
  t = 15.0
  frames = df.shape[0]
  fps = frames / t
  X_arr, ts_arr = get_slices(df, fps, 10)
  X_arr_r = X_arr.reshape((X_arr.shape[0], 1, 10, 156))
   # get prediction
  y_pred = model.predict(X_arr)
  # draw plot
  fig_name = FIG_FOLDER + 'model10_6364' + str(i + 1) + '.png'
  drawplt(ts_arr, y_pred, fig_name)
