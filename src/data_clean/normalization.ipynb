# %%
from google.colab import drive
drive.mount("/content/drive/", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
file_path = './drive/My Drive/dataset_dropped.csv'

# %%
ls './drive/My Drive/'
# Out:
# 'Colab Notebooks'/                      others/
#  dataset_dropped.csv                    photo/
# 'Detecting Hateful Users on Twitter'/  'PIMCO Values_June2019.pdf'
#  File_000.png

# %%
dataset = pd.read_csv(file_path)

# %%
dataset
# Out:
#       person_id      f_0      f_1       f_2  ...     f_207    f_208     f_209  label
# 0             1  763.665  423.757  0.695357  ...  1029.540  467.751  0.889465      1
# 1             1  764.497  420.297  0.699779  ...  1026.960  465.013  0.859063      1
# 2             1  760.839  422.602  0.698813  ...  1022.760  460.591  0.856230      1
# 3             1  760.238  424.103  0.710734  ...  1024.270  456.108  0.846358      1
# 4             1  759.816  423.623  0.716206  ...  1029.780  455.619  0.863378      1
# ...         ...      ...      ...       ...  ...       ...      ...       ...    ...
# 6776        165  543.977  231.061  0.747682  ...   702.692  237.674  0.717241      0
# 6777        165  544.836  230.999  0.723787  ...   701.967  238.856  0.725536      0
# 6778        165  542.765  230.620  0.749185  ...   701.383  238.439  0.729279      0
# 6779        165  541.472  231.441  0.737883  ...   700.063  234.745  0.769782      0
# ...

# %%
for i in range(0, 70, 3):
  x_name = 'f_' + str(i)
  y_name = 'f_' + str(i + 1)
  dataset[x_name] = dataset[x_name].div(1920)
  dataset[y_name] = dataset[y_name].div(1080)

# %%
dataset
# Out:
#       person_id       f_0       f_1  ...    f_208     f_209  label
# 0             1  0.397742  0.392368  ...  467.751  0.889465      1
# 1             1  0.398176  0.389164  ...  465.013  0.859063      1
# 2             1  0.396270  0.391298  ...  460.591  0.856230      1
# 3             1  0.395957  0.392688  ...  456.108  0.846358      1
# 4             1  0.395738  0.392244  ...  455.619  0.863378      1
# ...         ...       ...       ...  ...      ...       ...    ...
# 6776        165  0.283321  0.213945  ...  237.674  0.717241      0
# 6777        165  0.283769  0.213888  ...  238.856  0.725536      0
# 6778        165  0.282690  0.213537  ...  238.439  0.729279      0
# 6779        165  0.282017  0.214297  ...  234.745  0.769782      0
# 6780        165  0.281843  0.214113  ...  233.424  0.863333      0
#
# [6781 rows x 212 columns]

# %%
dataset.to_csv('dataset_n.csv')

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
def upload(name):
  uploaded = drive.CreateFile({'title': name})
  uploaded.SetContentFile(name)
  uploaded.Upload()
  print('Uploaded file with ID {}'.format(uploaded.get('id')))

# %%
upload('dataset_n.csv')
# Out:
# Uploaded file with ID 177hYahqp4Wrfv4Ytosq8fm-LgV_9L0r-
